# %% [markdown]
# # Constellation25 Data Analysis
# Automated forensic and metric analysis for this module.

# %%
import pandas as pd
import json

# Load module metrics
print('Initializing C25 Analysis Engine...')
# df = pd.read_csv('data/metrics.csv')
# df.head()
